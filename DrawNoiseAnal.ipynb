# %%
import numpy as np
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt

params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (6, 5),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
pylab.rcParams.update(params)

# %%
noise_level = [
    1,
    0.94,
    0.91,
    0.86,
    0.83,
    0.78]
mean = [
13.559153,
11.078285,
7.055494,
13.745366,
-0.182808,
-0.157841,
]
std = [
4.841263,
6.054214,
5.988536,
7.339302,
0.006954,
0.035335,
]
plt.plot(noise_level,mean)
plt.bar(noise_level, mean, width=0.01, yerr=std)
plt.ylabel('Performance')
plt.xlabel('Order Correctness(%)')
plt.gca().invert_xaxis()
#plt.xticks(range(len(mean)), [str(n) for n in noise_level])
plt.show()
